# %%
# !pip install pandas
# !pip install openpyxl
import pandas as pd
import openpyxl

# %%
df = pd.read_excel("CD2022_Populacao_2010_Compatibilizada_20231222.xlsx", header=2)

# %%
df
# Out:
#       Unnamed: 0                                                 UF  COD. UF  \
# 0            NaN                                                 RO     11.0
# 1            NaN                                                 RO     11.0
# 2            NaN                                                 RO     11.0
# 3            NaN                                                 RO     11.0
# 4            NaN                                                 RO     11.0
# ...          ...                                                ...      ...
# 5569         NaN                                                 DF     53.0
# 5570         NaN                                                NaN      NaN
# 5571         NaN  Nota: Para o cálculo das taxas de crescimento ...      NaN
# 5572         NaN                                                NaN      NaN
# 5573         NaN  Fonte: IBGE. Diretoria de Pesquisas - DPE -  C...      NaN
#
# ...

# %%
tabela_tratada = df.iloc[:5570, 1:]
tabela_tratada
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# ...

# %%
tabela_estado = tabela_tratada.groupby("UF")[["População Município 2010\n(Sinopse)", "População Censo 2022"]].sum().reset_index()

# %%
tabela_estado["Crescimento"] = tabela_estado["População Censo 2022"] - tabela_estado["População Município 2010\n(Sinopse)"]

# %%
tabela_estado.to_csv(r"H:\atividade 4\tabela_estado.csv", sep =";")

# %%
tabela_cidade = tabela_tratada.iloc[:, 3:]
tabela_cidade
# Out:
#           NOME DO MUNICÍPIO  População Município 2010\n(Sinopse)  \
# 0     Alta Floresta D'Oeste                              24392.0
# 1                 Ariquemes                              90353.0
# 2                    Cabixi                               6313.0
# 3                    Cacoal                              78574.0
# 4                Cerejeiras                              17029.0
# ...                     ...                                  ...
# 5565             Vianópolis                              12548.0
# 5566         Vicentinópolis                               7371.0
# 5567               Vila Boa                               4735.0
# 5568          Vila Propício                               5145.0
# 5569               Brasília                            2570160.0
#
#       População 2010 (Alterações de Limites até 2022)1  População Censo 2022
# 0                                              24392.0               21494.0
# ...

# %%
tabela_cidade.to_csv(r"H:\atividade 4\tabela_cidade.csv", sep =";")
